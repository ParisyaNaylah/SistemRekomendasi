# %%
import pandas as pd

df = pd.read_excel('usda.xlsx')

# Menampilkan 5 data pertama dengan kolom penting
sample_df = df[['FoodID', 'FoodCategory', 'FoodName', 'Energi']].head(5)

print(sample_df)
